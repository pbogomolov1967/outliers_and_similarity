# %% [markdown]
# ### If a cluster is stretched cloud of data points we can use Gaussian Mixture Model (GMM) to count of covariance of the data correctly

# %%
# %matplotlib inline
from gmm_probs import run_gmm_nb
run_gmm_nb()
